# %%
# set is unordered mutable hetergeous collection of unique records
# Note: set will eliminate duplicates 
# set is mutable but the elements within set have to be immutable
# set can contain int/float/str/bool/complex/None/tuple
# set cannot contain list/set/dict

# %%
myset={10,"leon",4.5,True,(4+5j),None,(10,20,30)}
print(type(myset))
print(myset)
print(dir(set))

# %%
companies={"tcs","wipro","cts"}
companies.add("Tsystems")
print(companies)
mycompanies={"infosys","tieto"}
companies.update(mycompanies)
print(companies)
#print("Poped is",companies.pop())
print(companies)
companies.remove("tcs")
try:
    companies.remove("tcs")
except:
    print("Key is not present!")

companies.discard("wipro")
companies.discard("wipro")

print(companies)

# %%
# Note: union |  intersection &  difference -  symmetric_difference ^
# issubset <= issuperset >=    disjoint

warehouse_items={"laptop","ups","router","printers"}
store_items={"laptop","mouse","keyboard"}

missing_in_store=warehouse_items.difference(store_items)
print(missing_in_store)
missing_in_store=warehouse_items - store_items
print(missing_in_store)

# %%
website_1={"leon","liam","russel","leon","leon"}
website_2={"adam","russel","leon","william"}

common_users=website_1.intersection(website_2)
print(common_users)
common_users=website_1 & website_2
print(common_users)

# %%
college_A={"maths","science","history","geography","maths"}
college_B={"maths","arts","science"}

all_courses=college_A.union(college_B)
print(all_courses)
all_courses=college_A | college_B
print(all_courses)

unique_courses=college_A.symmetric_difference(college_B)
print(unique_courses)

unique_courses=college_A ^ college_B
print(unique_courses)

# %%
website_1={"leon","liam","russel","leon","leon"}
website_2={"adam","russel","leon","william"}

print(website_1.issubset(website_2))
print(website_1 <= website_2)
print(website_1.issuperset(website_2))
print(website_1 >= website_2)
print(website_1.isdisjoint(website_2))

# %%
website_1={"leon","liam","russel","leon","leon"}
myset=frozenset(website_1)
print(dir(myset))

# %%
print(dir(set))

# %%
# control statements
# 1. sequential
# 2. conditional
# - branching (selection) if: else: elif:
# - looping (iteration) while: for:
# unconditonal break / continue

# %%
list1=[10,20,30]
print(list1[0],list1[1],list1[2]) # unpack using []
val1,val2,val3=list1 # multiple variable assingment
print(val1,val2,val3)

# %%
sensex=("tsystems","3/Mar/2026",1000)
#company,date,price=sensex # to unpack all values from smaller dataset
#print(company,date,price)  # readable and easy to maintain

# print(sensex[0],sensex[1],sensex[2]) # Note use this when you dont want to pack all values from larger dataset

# if you want to unpack all values use for loops (iterators)
#for each_val in sensex:
    #print(each_val)

# using iter conversion function on iterable(collections list/set/tuple/dict ) 
# you can iterate one value at a time using iterator next()
ref=iter(sensex)
print(next(ref))
print(next(ref))
print(next(ref))
#print(next(ref))

# %%
def foo():
    return 10,20,30

val1,val2,val3=foo()
print(val1,val2,val3)

# %%
# > < >= <= == != relational operators
var1,var2=100,200
# if var1 > var2:
#     print(f"{var1} is greater")
# else:
#     print(f"{var2} is greater")
print(f"Max is {max(var1,var2)}")

# %%
# and or not logical operators
var1,var2,var3=100,200,300

if var1 > var2 and var1 > var3:
    print(f"{var1} is greater")
elif var2 > var1 and var2 > var3:
    print(f"{var2} is greater")
else:
    print(f"{var3} is greater")

# %%
var1,var2,var3=100,200,300

if var1 > var2:
    if var1 > var3:
        print(f"{var1} is greater")
    else:
        print(f"{var3} is greater")
else:
    if var2 > var3:
        print(f"{var2} is greater")
    else:
        print(f"{var3} is greater")

print(f"Max is {max(var1,var2,var3)}")

# %%
# search (membership operators) using in / not in
# comparison value1==value2 
admin_users=["root","admin","adminstrator"]

user_name=input("Enter username")

if user_name in admin_users:
    print("You have full privileges")
else:
    print("You have guest privileges")

# %%
python_versions=[3.6,3.7,3.8,3.9]

version=float(input("Enter your version"))

if version not in python_versions:
    print("str.format() or cstrings!")
else:
    print("fstrings")

# %%
fact=1
num=int(input("Enter number"))
while num >0:
    fact*=num
    num-=1
print(f"Factorial is {fact}")

# %%
rev=0
total=0
num=int(input("Enter number"))
while num > 0:
    total+=num%10
    rev=rev*10+num%10
    num=num//10
print(f"reversed number is {rev}")
print(f"sum of digits is {total}")

# %%
# use for to unpack values from iterables
list1=[10,20,30,40,50]
for num in list1:
    print(num,end=" ")
print(" ")
tuple1=(10,20,30,40,50)
for num in tuple1:
    print(num,end=" ")
print(" ")
set1={10,20,30,40,50}
for num in set1:
    print(num,end=" ")
print(" ")
states={"maharashtra":"mumbai","karnataka":"bengaluru","tamilnadu":"chennai"}
for state in states: # Note: implicit i.e. list of keys() are returned
    print(state,end=" ")
print(" ")
for state in states:
    print(states[state],end=" ")
print(" ")
for state in states.keys(): # use keys() method explicitly!
    print(state,end=" ")
print(" ")
for capitals in states.values(): # [v1,v2...]
    print(capitals,end=" ")
print(" ")
for each_record in states.items(): # [(k1,v1),(k2,v2)...] 
    print(each_record[0],each_record[1],end=" ") # unpack tuple using []
print(" ")
for state,capital in states.items(): # [(k1,v1),(k2,v2)...] # use multiple variable assingment to unpack tuple!
    print(f"{capital} is in {state}")

# %%
# Generators act as an alternative for iterables or collections
# unlike collections they do not store values ( so memory footprint is less)
# Almost 90% of python API return generator functions
# Generators will always remember its state and will resume the call after suspension
# compute will only happen when there is a call
# There are 3 ways to access values from generators
# 1. use conversion functions for testing purpose i.e. to check values from generator functions
# 2. To access all values from generators use for loops
# for loops work on both iterables as well as generators!
# 3. use next() iterator to access one value at a time

# %%
print(range(5))

# %%
print(list(range(5)))
print(tuple(range(1,6))) # Here 6 is not included
print(set(range(5)))
print(list(range(10,101,5)))
#print(list(range(5)))

# %%
for num in range(1,6): # Here use for on range generator function
    print(num,end=" ")

# %%
ref=iter(range(10,16,1))
print(next(ref)) # fetech one value from generator!
print(next(ref))
print(next(ref))
print(next(ref))

# %%
index=0
list1=[10,20,30,40,50]
for num in list1:
    print(index,num)
    index+=1

# %%
# enumerate is a generator function which returns position and element as tuple
list1=[10,20,30,40,50]

print(enumerate(list1))
print(list(enumerate(list1)))
print(tuple(enumerate(list1)))
print(set(enumerate(list1)))
print(dict(enumerate(list1)))

# %%
tuple1=((10,20),(30,40))
print(dict(tuple1))

# %%
tuple1=((10,20,30),(30,40,50))
print(dict(tuple1))

# %%
tuple1=((10,20,30),(30,40,50))
print(list(tuple1))
print(tuple(tuple1))

# %%
list1=[10,20,30,40,50]

for index,value in enumerate(list1):
    print(index,value)

# %%
list1=[10,20,30,40,50]
ref=iter(enumerate(list1))
print(next(ref))
#print(next(ref))
#print(next(ref))

# %%
# comprehensions offer simplied sytax (pythonic way) to create a iterable or collection
# from existing collections
# list / set / dict comprehension 
# Note: There is no tuple comprehension it becomes a generator

# %%
list1=[]
for num in range(1,6):
    var=num*num
    list1.append(var)
print(list1)

# %%
list1=[num for num in range(1,6)]
print(list1)
list1=[0 for num in range(1,6)]
print(list1)
list1=[num*num for num in range(1,6)]
print(list1)
list1=[num*num*num for num in range(1,6)]
print(list1)

# %%
players=["ViRat","roHIT","    BumRAH    "]
players_lower=[each_player.strip().lower() for each_player in players]
myplayer=input("Enter your player")
if myplayer.lower() in players_lower:
    print(f"{myplayer} is playing today")
else:
    print(f"{myplayer} has to wait for next tournament!")

# %%
evens=[]
for num in range(1,11):
    if num%2==0:
        evens.append(num)
print(evens)
# conditional comprehension 
evens=[num for num in range(1,11) if num%2==0 ]
print(evens)
 
#labels=["even" if num%2==0  else "odd" for num in range(1,11)  ]
#print(labels)

# %%
logs=["ERROR :Insufficient Privileges","INFO :Start App","Warning : CPU HIGH Usage","ERROR : Memory Exhausted",
     "ERROR :Insufficient Privileges","ERROR :Insufficient Privileges"]
# set comprehension will eliminate duplicate lines
errors={each_line for each_line in logs if "ERROR" in each_line}
print(errors)

errors=[each_line for each_line in logs if "ERROR" in each_line]
errors=set(errors) # use set conversion function on list comprehension it becomes a set comprehension!
print(errors)

# %%
evens={num for num in range(1,11) if num%2==0}
print(evens)

# %%
customers=["piyush","leon"]
plans=["basic","premium","enterprise"]

offers=[(cust,plan) for cust in customers for plan in plans]
print(offers)

# %%
restaurants=[
    {"name":"good luck","address":"deccan"},
    {"name":"barbeque Nation","address":"deccan"},
    {"name":"abc farms","address":"kalyani nagar"},
    {"name":"nawab asia","address":"baner"},
    {"name":"barometer","address":"kothrud"}
]

current_location=input("Enter your location")

resto_nearby=[ each_resto["name"] for each_resto in restaurants if current_location == each_resto["address"]]

if any(resto_nearby):
    print(resto_nearby)
else:
    print("Please try a different location!")

# %%
restaurants={
    "deccan": {"good luck","barbeque Nation"},
    "kalyani nagar": {"abc farms"},
    "baner":{"barometer"}
}
current_location=input("Enter your location")
if current_location in restaurants.keys():
    print(restaurants[current_location])
else:
    print("Please try a different location")

# %%
players=["ViRat","roHIT","BumRAH"]
batters=["viRAT","ROHIT","GAYLE","Pollard"]
lower_players=[each_player.lower() for each_player in players]
lower_batters=[each_batter.lower() for each_batter in batters]
common_players=[]
for each_player in lower_players:
    if each_player in lower_batters:
        common_players.append(each_player)
        
print(common_players)

# %%
players=["ViRat","roHIT","BumRAH"]
batters=["viRAT","ROHIT","GAYLE","Pollard"]
lower_players=[each_player.lower() for each_player in players]
lower_batters=[each_batter.lower() for each_batter in batters]
common_players=[each_player for each_player in lower_players if each_player in lower_batters]
print(common_players)

# %%
players=["ViRat","roHIT","BumRAH"]
batters=["viRAT","ROHIT","GAYLE","Pollard"]
common_players=[each_player for each_player in [each_player.lower() for each_player in players] if each_player in [each_batter.lower() for each_batter in batters]]
print(common_players)

# %%
players={"ViRat","roHIT","BumRAH"}
batters={"viRAT","ROHIT","GAYLE","Pollard"}
lower_players={each_player.lower() for each_player in players}
lower_batters={each_batter.lower() for each_batter in batters}
print(lower_batters.intersection(lower_players))

# %%
gen1=(num*num for num in range(1,6))
print(gen1)
print(list(gen1))
gen1=(num*num for num in range(1,6))
print(tuple(gen1)) # trick!
gen1=(num*num for num in range(1,6))
print(set(gen1))

# %%
nums=[10,20,30,40,50]
print(sum(nums))
print(sum(nums))
print(sum(nums))

# %%
gen1=(num*num for num in range(1,6))
print(gen1)
print(sum(gen1))

#gen1=(num*num for num in range(1,6))
print(sum(gen1))

#gen1=(num*num for num in range(1,6))
print(sum(gen1))

# %%
gen1=(num*num for num in range(1,6))
ref=iter(gen1)
print(next(ref))
print(next(ref))
print(next(ref))

# %%
computer_names=["server-1","laptop-1","desktop-1","mylaptop"]
ip_addr=["8.8.8.8","192.168.10.1","172.16.10.3"]

dns={computer_names[index]:ip_addr[index] for index in range(len(ip_addr))}
print(dns)

# %%
computer_names=["server-1","laptop-1","desktop-1","mylaptop"]
ip_addr=["8.8.8.8","192.168.10.1","172.16.10.3"]
regions=["north-virginia","ohio","mumbai"]

print(dict(zip(computer_names,ip_addr)))
for instance,ip,region in zip(computer_names,ip_addr,regions):
    print(f"{instance} is launched in {region} has ip {ip}")

# %%
scores_students={"leon":88,"piyush":92,"Rainer":98,"David":89}
distinction_students={key:value for key,value in scores_students.items() if value>=90}
print(distinction_students)

# %%
scores_students={"leon":88,"piyush":92,"Rainer":98,"David":89}
reverse_students={value: key for key,value in scores_students.items() }
print(reverse_students)

# %%
scores_students={"leon":88,"piyush":92,"Rainer":98,"David":89}
reverse_students={f"Tsystems-{key}":value for key,value in scores_students.items() }
print(reverse_students)

# %%
# By default every function returns None
def function(): # function definition
    print("This is a function")

ref=function() # function call
print(ref)

# %%
def add(x,y): # x y are parameters
    return x+y

print(add(100,200)) # unnamed arguments
print(add((3+2j),(5+2j)))
print(add("tsystems","vinsys"))
print(add(12.4,6.7))

# %%
def foo():
    pass
class MyBase:
    pass
foo()

# %%
# Two problems function call will not give you information about the values
# if you change the order the result gets messed up!
def movie_details(movie,actor="*",year=0):
    print(f"{actor} acts in {movie} released in {year}")

movie_details("beautiful mind","russel crowe",2000) # unnamed arguments
#movie_details("training day",2000)
movie_details(1990,"braveheart","mel gibson") # unnamed arguments

# %%
def movie_details(movie,actor="*",year=0):
    print(f"{actor} acts in {movie} released in {year}")

movie_details(1990,"braveheart","mel gibson") # unnamed arguments
movie_details(year=1990,movie="braveheart",actor="mel gibson") # named arguments / kwargs

# %%
# create * in function definition to create a tuple 
# which can hold variable number of arguments
def add(*arg1): # (1,2,3)
    #print(type(arg1),arg1)
    total=0
    for num in arg1:
        total+=num
    return total
    
print(add(1,2,3))
print(add())
print(add(1,2,3,4,5))

# %%
# Note comma operator creates a tuple using () is optional
value=1,
print(type(value))

# %%
# Note: ** will create dictionary which can hold kwarguments
def add(**kwarg1):
    print(type(kwarg1),kwarg1)

print(add(x=10,y=20)) # kwarguments

# %%
def add(*arg1,**kwargs):
    total=0
    for num in arg1:
        total+=num
    for key,value in kwargs.items():
        total+=value
    return total
    
print(add(1,2,3))
print(add(x=100,y=200))
print(add(10,20,x=100,y=200))
print(add())

# %%
# Note: tuple first and then dict
def show(*args,**kwargs):
    print(args)
    print(kwargs)

#show(10,20,30) # unnamed args
#show(x=10,y=20,z=30) #kwargs
#show(10,var1=20,var2=30) # mix of both unnamed args /kwargs
show(100,var1=20,var2=30)

# %%
# %%writefile testfile.txt
# This is my first textfile
# I am happy and excited to work
# on python and use filehandling

# %%
pwd

# %%
fp=open("testfile.txt","r")
#print(dir(fp))
if fp.readable():
    print(fp.read())
    fp.seek(0) 
    print(fp.read())
    fp.seek(11) 
    print(fp.read())
fp.close()

# %%
# context managers will automatically close the file  
with open("gratitude.txt","w") as fs:
    fs.write("Thank you GOD for birds thy sing\n")
    fs.write("Thank you GOD for food we eat\n")
    fs.write("Thank you GOD for world so sweet\n")
    fs.write("Thank you GOD for everything\n")

# %%
with open("gratitude.txt","r") as fs:
    print(fs.readline().strip("\n"))
    print(fs.readline().strip("\n"))
    print(fs.readline().strip("\n"))

# %%
count_food=0
total_lines=0
with open("gratitude.txt","r") as fs:
    line=fs.readline()
    while line:
        if "food" in line:
            count_food+=1
        total_lines+=1
        line=fs.readline()

print(f"Total lines {total_lines}")
print(f"word food appears {count_food} times")
# Out:
# Total lines 4
# word food appears 1 times

# %%
with open("gratitude.txt","r") as fs:
    all_data=fs.readlines()
    print(all_data)
    print(f"total number of lines {len(all_data)}")
    print("First line is",all_data[0])
    print("second and third lines ...")
    for each_row in all_data[1:3]:
        print(each_row)
    print("Last line is",all_data[-1])
    all_data.insert(1,"Tsystems is awesome!\n") # add second line
    del all_data[0] # delete first line
    all_data[1]="THANK YOU LORD FOR FOOD WE EAT\n" # update
    print(all_data)
    
with open("gratitude_copy.txt","w") as fs:
    for each_line in all_data:
        fs.write(each_line)
# Out:
# ['Thank you GOD for birds thy sing\n', 'Thank you GOD for food we eat\n', 'Thank you GOD for world so sweet\n', 'Thank you GOD for everything\n']
# total number of lines 4
# First line is Thank you GOD for birds thy sing
#
# second and third lines ...
# Thank you GOD for food we eat
#
# Thank you GOD for world so sweet
#
# Last line is Thank you GOD for everything
#
# ['Tsystems is awesome!\n', 'THANK YOU LORD FOR FOOD WE EAT\n', 'Thank you GOD for world so sweet\n', 'Thank you GOD for everything\n']

# %%
print(dir(list))
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %%
collection=["row row row your boat","gently down the stream","merrily merrily merrily merrily","life is but a dream"]

#newcollection=[ each_line+"\n" for each_line in collection ]
#print(newcollection)
#with open("rhyme.txt","w") as fs:
    #fs.writelines(newcollection)

# %%
collection=["row row row your boat","gently down the stream","merrily merrily merrily merrily","life is but a dream"]
with open("rhyme.txt","w") as fs:
    for each_line in collection:
        fs.write(each_line+"\n")

# %%
# %%writefile emp.csv
# leon,4567823,tsystems,567.89
# david,823123,cts,467.89
# piyush,45673,bmc,267.89
# Out:
# Overwriting emp.csv

# %%
total=0
with open("emp.csv","r") as fs:
    all_data=fs.readlines()
    for each_row in all_data:
        each_row=each_row.strip("\n").split(",")
        total+=float(each_row[3])
print("Total is ",total)
# Out:
# Total is  1303.67

# %%
import csv
total=0
with open("emp.csv","r") as fs:
    data=csv.reader(fs
    for record in data:
        total+=float(record[3])

print("Total is",total)
# Out:
# Total is 1303.67

# %%
import csv
import matplotlib.pyplot as plt

science_fiction=[]
sports=[]

with open("disney_plus_titles.csv","r",encoding='utf-8') as fs:
    data=csv.reader(fs)
    next(data)
    for each_row in data:
        if "Science Fiction" in each_row[10]:
            science_fiction.append(each_row[2])
        if "Sports" in each_row[10]:
            sports.append(each_row[2])



#print("Science fiction titles",len(science_fiction))
#print("Sports titles",len(sports))
plt.pie([len(science_fiction),len(sports)],labels=["Science Fiction","Sports"])
plt.show()
